# %%
# !git clone https://github.com/kimdonggyu2008/pflowtts_pytorch.git
# %cd pflowtts_pytorch
# !git submodule init; git submodule update
# Out:
# Cloning into 'pflowtts_pytorch'...
# remote: Enumerating objects: 496, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 496 (delta 195), reused 150 (delta 150), pack-reused 254
# Receiving objects: 100% (496/496), 10.41 MiB | 25.14 MiB/s, done.
# Resolving deltas: 100% (257/257), done.
# /kaggle/working/pflowtts_pytorch

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.2 MB/s eta 0:00:00
# ...
# done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 2.6 MB/s eta 0:00:00
# done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 8.5 MB/s eta 0:00:00
# done
# ...
# done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.8/103.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 67.1 MB/s eta 0:00:00
# ...

# %%
# Cython-version Monotonoic Alignment Search
# !python setup.py build_ext --inplace
# Out:
# Compiling pflow/utils/monotonic_align/core.pyx because it changed.
# [1/1] Cythonizing pflow/utils/monotonic_align/core.pyx
# /opt/conda/lib/python3.10/site-packages/Cython/Compiler/Main.py:381: FutureWarning: Cython directive 'language_level' not set, using '3str' for now (Py3). This has changed from earlier releases! File: /kaggle/working/pflowtts_pytorch/pflow/utils/monotonic_align/core.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# performance hint: pflow/utils/monotonic_align/core.pyx:7:5: Exception check on 'maximum_path_each' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare 'maximum_path_each' as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on 'maximum_path_each' to allow an error code to be returned.
# performance hint: pflow/utils/monotonic_align/core.pyx:38:6: Exception check on 'maximum_path_c' will always require the GIL to be acquired.
# ...

# %% [raw]
# train_filelist_path:/kaggle/input/lj-speech-filelist/ljs_audio_text_train_filelist.txt
# valid_filelist_path:/kaggle/input/lj-speech-filelist/ljs_audio_text_val_filelist.txt

# %%
# %cd /kaggle/working/pflowtts_pytorch/pflow/utils
# Out:
# /kaggle/working/pflowtts_pytorch/pflow/utils

# %%
# !sudo apt install espeak -y
# Out:
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 80 not upgraded.
# Need to get 1220 kB of archives.
# After this operation, 3060 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportaudio2 amd64 19.6.0-1build1 [65.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libsonic0 amd64 0.2.0-8 [13.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 espeak-data amd64 1.48.04+dfsg-8build1 [932 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libespeak1 amd64 1.48.04+dfsg-8build1 [147 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 espeak amd64 1.48.04+dfsg-8build1 [61.8 kB]
# Fetched 1220 kB in 0s (3053 kB/s)
#
# ...

# %%
# !python generate_data_statistics.py -i ljspeech.yaml
# Out:
# Traceback (most recent call last):
#   File "/kaggle/working/pflowtts_pytorch/pflow/utils/generate_data_statistics.py", line 115, in <module>
#     main()
#   File "/kaggle/working/pflowtts_pytorch/pflow/utils/generate_data_statistics.py", line 103, in main
#     text_mel_datamodule.setup()
#   File "/kaggle/working/pflowtts_pytorch/pflow/utils/../../pflow/data/text_mel_datamodule.py", line 58, in setup
#     self.trainset = TextMelDataset(  # pylint: disable=attribute-defined-outside-init
#   File "/kaggle/working/pflowtts_pytorch/pflow/utils/../../pflow/data/text_mel_datamodule.py", line 142, in __init__
#     self.filepaths_and_text = parse_filelist(filelist_path)
#   File "/kaggle/working/pflowtts_pytorch/pflow/utils/../../pflow/data/text_mel_datamodule.py", line 16, in parse_filelist
#     with open(filelist_path, encoding="utf-8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/pflowtts_pytorch/data/filelists/ljs_audio_text_train_filelist.txt'
